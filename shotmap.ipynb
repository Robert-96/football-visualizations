# %% [markdown]
# # Football Shotmaps

# %%
from football_shotmap.scrape import get_shots_data
from football_shotmap.shotmap import create_shotmap_fig_form_data

# %%
player = "Diogo Jota"
year = "2021"

# %%
data = await get_shots_data(player, year)

# %%
fig = create_shotmap_fig_form_data(player, 2020, data)
